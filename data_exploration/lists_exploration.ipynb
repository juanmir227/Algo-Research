# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
from varname import nameof
import seaborn as sb

lists = ['created_apps', 'total_transaction_amount', 'total_sender_number', 'total_receiver_number', 'total_active_accounts', 'mean_transaction_amount_per_sender',
'mean_transaction_amount_per_receiver', 'mean_amount_of_unique_receiver_for_sender', 'mean_amount_of_unique_sender_for_receiver', 'only_sender_accounts',
'only_receiver_accounts', 'percent_of_senders_only_senders', 'percent_of_receivers_only_receivers', 'percent_of_accounts_only_senders', 'percent_of_accounts_only_receivers',
'sender_average_transacted_accounts', 'receiver_average_transacted_accounts','sender_average_transacted_with_same_accounts', 'receiver_average_transacted_with_same_accounts',
'most_frequent_ids', 'percentage_of_total_transactions_per_asset', 'unique_senders_per_asset', 'unique_receivers_per_asset', 'unique_accounts_per_asset',
'percentage_of_total_accounts_per_asset', 'transactions_one_algo', 'involved_accounts_per_type', 'involved_senders_per_type', 'involved_receivers_per_type',
'percentage_of_total_accounts_per_type', 'transaction_amount_in_microalgo', 'closing_transactions_count', 'more_than_one_algo',
'more_than_one_algo_percentage', 'mean_amount_of_algo_sent']

with open('/home/juaneto8/Documents/Projects/Algorand/data_acquisition/lists_csv/data_lists', 'rb') as fp:
    data_lists = pickle.load(fp)

created_apps = data_lists[0]
total_transaction_amount = data_lists[1]
total_sender_number = data_lists[2]
total_receiver_number = data_lists[3]
total_active_accounts = data_lists[4]
mean_transaction_amount_per_sender = data_lists[5]
mean_transaction_amount_per_receiver = data_lists[6]
mean_amount_of_unique_receiver_for_sender = data_lists[7]
mean_amount_of_unique_sender_for_receiver = data_lists[8]
only_sender_accounts = data_lists[9]
only_receiver_accounts = data_lists[10]
percent_of_senders_only_senders = data_lists[11]
percent_of_receivers_only_receivers = data_lists[12]
percent_of_accounts_only_senders = data_lists[13]
percent_of_accounts_only_receivers = data_lists[14]
sender_average_transacted_accounts = data_lists[15]
receiver_average_transacted_accounts = data_lists[16]
sender_average_transacted_with_same_accounts = data_lists[17]
receiver_average_transacted_with_same_accounts = data_lists[18]
most_frequent_ids = data_lists[19]
percentage_of_total_transactions_per_asset = data_lists[20]
unique_senders_per_asset = data_lists[21]
unique_receivers_per_asset = data_lists[22]
unique_accounts_per_asset = data_lists[23]
percentage_of_total_accounts_per_asset = data_lists[24]
transactions_one_algo = data_lists[24]
involved_accounts_per_type = data_lists[25]
involved_senders_per_type = data_lists[26]
involved_receivers_per_type = data_lists[27]
percentage_of_total_accounts_per_type = data_lists[28]
transaction_amount_in_microalgo = data_lists[29]
closing_transactions_count = data_lists[30]
more_than_one_algo = data_lists[31]
more_than_one_algo_percentage = data_lists[32]
mean_amount_of_algo_sent = data_lists[33]

# %%
sb.lineplot(np.array(total_transaction_amount)/500)
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Mean amount of transactions per block per chunk')
plt.show()

sb.lineplot(np.array(mean_amount_of_algo_sent))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Mean amount of algo sent per block per chunk')
# Out:
# Text(0.5, 1.0, 'Mean amount of algo sent per block per chunk')

# %%
sb.lineplot(np.array(total_sender_number))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()

sb.lineplot(np.array(total_receiver_number))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique receivers per chunk')
plt.show()

# %%
sb.lineplot(np.array(total_active_accounts))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()

sb.lineplot(np.array(mean_transaction_amount_per_sender))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()

# %%
sb.lineplot(np.array(mean_transaction_amount_per_receiver))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()

# %%
sb.lineplot(np.array(only_sender_accounts))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()

sb.lineplot(np.array(only_receiver_accounts))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()

# %%
sb.lineplot(np.array(percent_of_senders_only_senders))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()

sb.lineplot(np.array(percent_of_receivers_only_receivers))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()
sb.lineplot(np.array(percent_of_receivers_only_receivers))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()

# %%
sb.lineplot(np.array(more_than_one_algo))
plt.xticks(np.arange(0,15, step = 1))
plt.grid(True)
plt.title('Total unique senders per chunk')
plt.show()
